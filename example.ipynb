# %%
# !pip install selenium
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
# Out:
# Requirement already satisfied: selenium in /home/ghiffaryr/.local/lib/python3.8/site-packages (4.6.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in /home/ghiffaryr/.local/lib/python3.8/site-packages (from selenium) (1.26.12)
# Requirement already satisfied: trio-websocket~=0.9 in /home/ghiffaryr/.local/lib/python3.8/site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in /home/ghiffaryr/.local/lib/python3.8/site-packages (from selenium) (2022.9.24)
# Requirement already satisfied: trio~=0.17 in /home/ghiffaryr/.local/lib/python3.8/site-packages (from selenium) (0.22.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in /usr/lib/python3/dist-packages (from urllib3[socks]~=1.26->selenium) (1.6.8)
# Requirement already satisfied: wsproto>=0.14 in /home/ghiffaryr/.local/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.10 in /home/ghiffaryr/.local/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.10)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9; python_version < "3.11" in /home/ghiffaryr/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: outcome in /home/ghiffaryr/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /home/ghiffaryr/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/ghiffaryr/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: idna in /home/ghiffaryr/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.7)
# Requirement already satisfied: sortedcontainers in /home/ghiffaryr/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /home/ghiffaryr/.local/lib/python3.8/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Reading package lists... Done
# E: Could not open lock file /var/lib/apt/lists/lock - open (13: Permission denied)
# E: Unable to lock directory /var/lib/apt/lists/
# W: Problem unlinking the file /var/cache/apt/pkgcache.bin - RemoveCaches (13: Permission denied)
# W: Problem unlinking the file /var/cache/apt/srcpkgcache.bin - RemoveCaches (13: Permission denied)
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# cp: cannot stat '/usr/lib/chromium-browser/chromedriver': No such file or directory

# %%
from feedback_generator import generator

for num in range(10):
    print(generator("coffee"))
# Out:
# Your company is truly upstanding and is behind its product 100%. If you want real marketing that works and effective implementation - coffee's got you covered. I am really satisfied with my coffee. I don't always clop, but when I do, it's because of coffee.
# I didn't even need training. I'm good to go. Nice work on your coffee. I was amazed at the quality of coffee.
# I would be lost without coffee. Coffee is the most valuable business resource we have EVER purchased. We have no regrets!
# Best. Product. Ever! Needless to say we are extremely satisfied with the results.
# Coffee is both attractive and highly adaptable. We have no regrets! Needless to say we are extremely satisfied with the results.
# I will let my mum know about this, she could really make use of coffee! We're loving it.
# I can't say enough about coffee. Coffee was worth a fortune to my company. I don't know what else to say. Just what I was looking for.
# I would be lost without coffee. It fits our needs perfectly.
# It really saves me time and effort. coffee is exactly what our business has been lacking. Very easy to use. I would gladly pay over 600 dollars for coffee. Since I invested in coffee I made over 100,000 dollars profits.
# I will let my mum know about this, she could really make use of coffee! I have gotten at least 50 times the value from coffee. I didn't even need training.
